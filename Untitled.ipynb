# %%
# !python -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\itadmin\appdata\local\programs\python\python313\lib\site-packages (25.1.1)
# Collecting pip
#   Downloading pip-25.2-py3-none-any.whl.metadata (4.7 kB)
# Downloading pip-25.2-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----------------- ---------------------- 0.8/1.8 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 9.4 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 25.1.1
#     Uninstalling pip-25.1.1:
#       Successfully uninstalled pip-25.1.1
# Successfully installed pip-25.2

# %%
# !pip install requests beautifulsoup4 pandas
# Out:
# Requirement already satisfied: requests in c:\users\itadmin\appdata\local\programs\python\python313\lib\site-packages (2.32.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\itadmin\appdata\local\programs\python\python313\lib\site-packages (4.13.4)
# Requirement already satisfied: pandas in c:\users\itadmin\appdata\local\programs\python\python313\lib\site-packages (2.3.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\itadmin\appdata\local\programs\python\python313\lib\site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\itadmin\appdata\local\programs\python\python313\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\itadmin\appdata\local\programs\python\python313\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\itadmin\appdata\local\programs\python\python313\lib\site-packages (from requests) (2025.8.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\itadmin\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\itadmin\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4) (4.14.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\itadmin\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\itadmin\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\itadmin\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\itadmin\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\itadmin\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

base_url = "https://www.realproperty.pk/houses-for-sale-islamabad?page="
headers = {"User-Agent": "Mozilla/5.0"}

all_data = []

for page in range(1, 6):  # scrape first 5 pages
    url = base_url + str(page)
    print(f"Scraping page {page} -> {url}")
    
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, "html.parser")
    
    listings = soup.find_all("div", class_="single-property-box")
    
    for listing in listings:
        # Title
        title_tag = listing.find("div", class_=lambda c: c and "property-for-title" in c)
        title = title_tag.get_text(strip=True) if title_tag else None

        # Price
        price_tag = listing.find("h4")
        price = price_tag.get_text(strip=True) if price_tag else "No Price"

        # Location
        location_tag = listing.find("div", class_=lambda c: c and "property-address" in c)
        location = location_tag.get_text(strip=True) if location_tag else None

        # Fallbacks for missing data
        if not title:
            title = f"House For Sale {location if location else ''}".strip() or "House For Sale"
        
        if not location:
            if "Islamabad" in title:
                location = "Islamabad"
            else:
                location = "No Location"

        # Link
        link_tag = listing.find("a")
        link = "https://www.realproperty.pk" + link_tag["href"] if link_tag else "No Link"

        all_data.append({
            "Title": title,
            "Price": price,
            "Location": location,
            "Link": link
        })
    
    time.sleep(1)

# Save
df = pd.DataFrame(all_data)
df.to_csv("realproperty_islamabad_autofilled.csv", index=False, encoding="utf-8-sig")
print("✅ Scraped total", len(df), "listings (auto-filled missing values)")
df.head(10)
# Out:
# Scraping page 1 -> https://www.realproperty.pk/houses-for-sale-islamabad?page=1
# Scraping page 2 -> https://www.realproperty.pk/houses-for-sale-islamabad?page=2
# Scraping page 3 -> https://www.realproperty.pk/houses-for-sale-islamabad?page=3
# Scraping page 4 -> https://www.realproperty.pk/houses-for-sale-islamabad?page=4
# Scraping page 5 -> https://www.realproperty.pk/houses-for-sale-islamabad?page=5
# ✅ Scraped total 200 listings (auto-filled missing values)
#             Title           Price     Location  \
# 0  House For Sale  PKR11.00 Crore  No Location
# 1  House For Sale  PKR24.00 Crore  No Location
# 2  House For Sale   PKR8.00 Crore  No Location
# 3  House For Sale   PKR3.60 Crore  No Location
# 4  House For Sale  Call For Price  No Location
# 5  House For Sale   PKR4.80 Crore  No Location
# 6  House For Sale   PKR1.18 Crore  No Location
# 7  House For Sale   PKR6.50 Crore  No Location
# 8  House For Sale  PKR16.00 Crore  No Location
# 9  House For Sale  PKR16.00 Crore  No Location
#
#                                                 Link
# 0  https://www.realproperty.pk/property/1-kanal-h...
# 1  https://www.realproperty.pk/property/40x120-ho...
# 2  https://www.realproperty.pk/property/kanal-hou...
# 3  https://www.realproperty.pk/property/house-for...
# 4  https://www.realproperty.pk/property/house-for...
# 5  https://www.realproperty.pk/property/house-for...
# 6  https://www.realproperty.pk/property/grey-stru...
# 7  https://www.realproperty.pk/property/bahria-en...
# 8  https://www.realproperty.pk/property/double-st...
# 9  https://www.realproperty.pk/property/5-marla-h...

# %%
import re

def clean_price(price_str):
    if not price_str or "No Price" in price_str:
        return None
    
    price_str = price_str.replace("PKR", "").strip()
    
    # Crore (1 crore = 10,000,000)
    match = re.search(r"([\d.]+)\s*Crore", price_str, re.IGNORECASE)
    if match:
        return float(match.group(1)) * 10000000
    
    # Lakh (1 lakh = 100,000)
    match = re.search(r"([\d.]+)\s*Lakh", price_str, re.IGNORECASE)
    if match:
        return float(match.group(1)) * 100000
    
    # Thousand
    match = re.search(r"([\d.]+)\s*Thousand", price_str, re.IGNORECASE)
    if match:
        return float(match.group(1)) * 1000
    
    # If just number
    match = re.search(r"([\d,]+)", price_str)
    if match:
        return float(match.group(1).replace(",", ""))
    
    return None

# %%
# Load your cleaned dataset
df = pd.read_csv("realproperty_islamabad_autofilled.csv")

# Apply cleaning function
df["Price_PKR"] = df["Price"].apply(clean_price)

# Save updated dataset
df.to_csv("realproperty_islamabad_cleaned.csv", index=False, encoding="utf-8-sig")

print("✅ Cleaned prices added")
df.head(10)
# Out:
# ✅ Cleaned prices added
#             Title           Price     Location  \
# 0  House For Sale  PKR11.00 Crore  No Location
# 1  House For Sale  PKR24.00 Crore  No Location
# 2  House For Sale   PKR8.00 Crore  No Location
# 3  House For Sale   PKR3.60 Crore  No Location
# 4  House For Sale  Call For Price  No Location
# 5  House For Sale   PKR4.80 Crore  No Location
# 6  House For Sale   PKR1.18 Crore  No Location
# 7  House For Sale   PKR6.50 Crore  No Location
# 8  House For Sale  PKR16.00 Crore  No Location
# 9  House For Sale  PKR16.00 Crore  No Location
#
#                                                 Link    Price_PKR
# 0  https://www.realproperty.pk/property/1-kanal-h...  110000000.0
# 1  https://www.realproperty.pk/property/40x120-ho...  240000000.0
# 2  https://www.realproperty.pk/property/kanal-hou...   80000000.0
# 3  https://www.realproperty.pk/property/house-for...   36000000.0
# 4  https://www.realproperty.pk/property/house-for...          NaN
# 5  https://www.realproperty.pk/property/house-for...   48000000.0
# 6  https://www.realproperty.pk/property/grey-stru...   11800000.0
# 7  https://www.realproperty.pk/property/bahria-en...   65000000.0
# 8  https://www.realproperty.pk/property/double-st...  160000000.0
# 9  https://www.realproperty.pk/property/5-marla-h...  160000000.0

# %%
df["Price_PKR"].mean()
# Out:
# np.float64(48032993.43617021)

# %%
df.loc[df["Price_PKR"].idxmin()]
df.loc[df["Price_PKR"].idxmax()]
# Out:
# Title                                           House For Sale
# Price                                           PKR80.00 Crore
# Location                                           No Location
# Link         https://www.realproperty.pk/property/g13-full-...
# Price_PKR                                          800000000.0
# Name: 52, dtype: object

# %%
df.groupby("Location")["Price_PKR"].mean().sort_values(ascending=False)
# Out:
# Location
# F-8, Islamabad                                 2.166667e+08
# F-11, Islamabad                                1.600000e+08
# Gulberg Green, Islamabad                       1.100000e+08
# DHA Phase 5, DHA Defence                       1.100000e+08
# Ali Pur, Islamabad                             1.066667e+08
# Islamabad                                      1.016667e+08
# B-17 - ock B, B-17 -  MPCHS - Multi Gardens    8.000000e+07
# DHA Defence, Islamabad                         7.500000e+07
# DHA Phase 2 - Sector G, DHA Phase 2            7.500000e+07
# DHA Phase 1 - Sector A, DHA Phase 1            7.000000e+07
# G-11, Islamabad                                6.300000e+07
# DHA Phase 2 - Sector D, DHA Phase 2            5.500000e+07
# Bahria Enclave, Islamabad                      4.850000e+07
# No Location                                    4.803299e+07
# G-8, Islamabad                                 4.800000e+07
# I-11, Islamabad                                4.125000e+07
# CBR Town, Islamabad                            3.800000e+07
# DHA Phase 1 - Sector F, DHA Phase 1            3.750000e+07
# E-11, Islamabad                                3.600000e+07
# I-14, Islamabad                                3.550000e+07
# Gulberg, Islamabad                             3.550000e+07
# G-15, Islamabad                                3.433333e+07
# F-17, Islamabad                                2.925000e+07
# Bahria Enclave -  Sector C1                    2.800000e+07
# B-17 -  Ideas Tower                            2.750000e+07
# Bani Gala, Islamabad                           2.666667e+07
# B-17 -  MPCHS  Multi Gardens                   2.600001e+07
# B-17, Islamabad                                2.575000e+07
# Soan Garden, Islamabad                         2.025000e+07
# Humak, Islamabad                               1.900000e+07
# Bahria Town -  Others                          1.800000e+07
# Shaheen Town, Islamabad                        1.800000e+07
# I-10, Islamabad                                1.700000e+07
# Chatha Bakhtawar, Islamabad                    1.600000e+07
# Capital Enclave, Islamabad                     1.500000e+07
# New Shakrial, Islamabad                        1.350000e+07
# Ghauri Town -   Phase 2                        1.180000e+07
# D-17, Islamabad                                1.150000e+07
# Sangjani, Islamabad                            1.100000e+07
# Garden Town, Islamabad                         1.050000e+07
# Bhara kahu, Islamabad                          8.200047e+06
# Ghauri Town, Islamabad                         7.400026e+06
# Simly Dam Road, Islamabad                      4.333383e+06
# GT Road, Islamabad                             9.700000e+01
# H-13, Islamabad                                8.000000e+01
# Alipur Farash, Islamabad                       7.333333e+01
# E-14, Islamabad                                5.500000e+01
# Taramrri, Islamabad                            5.250000e+01
# G-13, Islamabad                                3.200000e+01
# Canyon Views, Islamabad                        1.000000e+00
# Name: Price_PKR, dtype: float64
